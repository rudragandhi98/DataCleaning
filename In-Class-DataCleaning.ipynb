# %% [markdown]
# ### Loading the Dataset

# %%
# Loading the needed packages 
import pandas as pd 
import numpy as np

df = pd.read_csv('BL-Flickr-Images-Book-truncated50.csv')
df.head()
# Out:
#    Identifier             Edition Statement  \
# 0         206                           NaN
# 1         216                           NaN
# 2         218                           NaN
# 3         472                           NaN
# 4         480  A new edition, revised, etc.
#
#                    Place of Publication Date of Publication  \
# 0                                London         1879 [1878]
# 1              London; Virtue & Yorston                1868
# 2                             Londinium                1869
# 3  \u004c\u006f\u006e\u0064\u006f\u006e                1851
# 4                                London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                  Contributors  Corporate Author  \
# 0      A. A.                               FORBES, Walter.               NaN
# 1  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 2  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 3  A., E. S.                   Appleyard, Ernest Silvanus.               NaN
# 4  A., E. S.                           BROOME, John Henry.               NaN
#
#    Corporate Contributors  Former owner  Engraver Issuance type  \
# 0                     NaN           NaN       NaN   monographic
# 1                     NaN           NaN       NaN   monographic
# 2                     NaN           NaN       NaN   monographic
# 3                     NaN           NaN       NaN   monographic
# 4                     NaN           NaN       NaN   monographic
#
#                                           Flickr URL  \
# 0  http://www.flickr.com/photos/britishlibrary/ta...
# 1  http://www.flickr.com/photos/britishlibrary/ta...
# 2  http://www.flickr.com/photos/britishlibrary/ta...
# 3  http://www.flickr.com/photos/britishlibrary/ta...
# 4  http://www.flickr.com/photos/britishlibrary/ta...
#
#                             Shelfmarks
# 0    British Library HMNTS 12641.b.30.
# 1    British Library HMNTS 12626.cc.2.
# 2    British Library HMNTS 12625.dd.1.
# 3  British Library HMNTS 10369.bbb.15.
# 4     British Library HMNTS 9007.d.28.

# %% [markdown]
# ### Dropping columns

# %%
to_drop = ['Edition Statement','Corporate Author','Corporate Contributors','Former owner','Engraver','Contributors','Issuance type','Shelfmarks', 'Flickr URL']
df.drop(to_drop, inplace=True, axis=1)
df.head()
# Out:
#    Identifier                  Place of Publication Date of Publication  \
# 0         206                                London         1879 [1878]
# 1         216              London; Virtue & Yorston                1868
# 2         218                             Londinium                1869
# 3         472  \u004c\u006f\u006e\u0064\u006f\u006e                1851
# 4         480                                London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author
# 0      A. A.
# 1  A., A. A.
# 2  A., A. A.
# 3  A., E. S.
# 4  A., E. S.

# %%
# Set Index as Identifier 
df = df.set_index('Identifier')
df.head()
# Out:
#                             Place of Publication Date of Publication  \
# Identifier
# 206                                       London         1879 [1878]
# 216                     London; Virtue & Yorston                1868
# 218                                    Londinium                1869
# 472         \u004c\u006f\u006e\u0064\u006f\u006e                1851
# 480                                       London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# 480         [The World in which I live, and my place in it...  A., E. S.

# %%
# Looking at a specfic location 
df.loc[1905:, 'Date of Publication'].head(10)
# Out:
# Identifier
# 1905           1888
# 1929    1839, 38-54
# 2836           1897
# 2854           1865
# 2956        1860-63
# 2957           1873
# 3017           1866
# 3131           1899
# 4598           1814
# 4884           1820
# Name: Date of Publication, dtype: object

# %%
# Removing characters from the date of publication
rem = df['Date of Publication'].str.extract(r'^(\d{4})', expand=False)
rem.head()
# Out:
# Identifier
# 206    1879
# 216    1868
# 218    1869
# 472    1851
# 480    1857
# Name: Date of Publication, dtype: object

# %%
df['Date of Publication'] = pd.to_numeric(rem)
df['Date of Publication'].dtype
df['Date of Publication'].isnull().sum() / len(df)
# Out:
# 0.22448979591836735

# %%
# Looking at top 10 Place of Publications
df['Place of Publication'].head(10)
# Out:
# Identifier
# 206                                   London
# 216                 London; Virtue & Yorston
# 218                                Londinium
# 472     \u004c\u006f\u006e\u0064\u006f\u006e
# 480                                   London
# 481                                   London
# 519                                   LONDON
# 667      pp. 40. G. Bryan & Co: Oxford, 1898
# 874                                  London]
# 1143                               Λονδίνιον
# Name: Place of Publication, dtype: object

# %%
# Keeping Rows that consist of only LONDON as a Place of Publication 
new = df[df['Place of Publication'].str.contains("London")]

# %%
# Printing the new dataframe (Head)
new.head()
# Out:
#                 Place of Publication  Date of Publication  \
# Identifier
# 206                           London               1879.0
# 216         London; Virtue & Yorston               1868.0
# 480                           London               1857.0
# 481                           London               1875.0
# 874                          London]                  NaN
#
#                        Publisher  \
# Identifier
# 206             S. Tinsley & Co.
# 216                 Virtue & Co.
# 480         Wertheim & Macintosh
# 481            William Macintosh
# 874                          NaN
#
#                                                         Title     Author
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 480         [The World in which I live, and my place in it...  A., E. S.
# 481         [The World in which I live, and my place in it...  A., E. S.
# 874         A Warning to the inhabitants of England, and L...     Remaʿ.

# %%
# Printing the new dataframe (Tail)
new.tail()
# Out:
#            Place of Publication  Date of Publication        Publisher  \
# Identifier
# 14466                    London                  NaN     Adams & King
# 15141                    London               1893.0  T. Fisher Unwin
# 15146                    London               1894.0  T. Fisher Unwin
# 16543                    London               1816.0      John Murray
# 18173                    London               1804.0    Vernor & Hood
#
#                                                         Title  \
# Identifier
# 14466       The Historie of Eald Street, now called Old St...
# 15141       The New Egypt. A social sketch. [Edited by J. ...
# 15146       Tiberius: a drama ... With introduction by W. ...
# 16543       The Narrative of Robert Adams, a sailor, who w...
# 18173       [The Works of the late Right Honourable Joseph...
#
#                                         Author
# Identifier
# 14466                                      NaN
# 15141       ADAMS, Francis William Lauderdale.
# 15146       ADAMS, Francis William Lauderdale.
# 16543                   Adams, Robert - Sailor
# 18173              ADDISON, Joseph - Right Hon

# %%
# Load the clean data into a new csv file 
new.to_csv('New-BL-Flickr-Images-Book-truncated50.csv')
